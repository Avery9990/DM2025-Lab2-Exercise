# %%
# ============================================================
# ✅ Test code for environment setup
# ============================================================

# --- import libraries ---
import dotenv
from google import genai
import langextract
import gensim
import tensorflow
import tensorflow_hub
import keras
import ollama
import langchain
from langchain_community import utils
from langchain_core import prompts
from langchain_google_genai import chat_models
from bs4 import BeautifulSoup
import chromadb
import gradio
import jupyter
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly
import seaborn as sns
import nltk
import umap
import pymupdf

# --- Notebook magic (only for Jupyter) ---
# %matplotlib inline

# --- print version info ---
print("✅ Installed package versions:")
print("----------------------------------")
print("gensim:      ", gensim.__version__)
print("tensorflow:  ", tensorflow.__version__)
print("keras:       ", keras.__version__)
print("pandas:      ", pd.__version__)
print("numpy:       ", np.__version__)
print("matplotlib:  ", plt.matplotlib.__version__)
print("plotly:      ", plotly.__version__)
print("seaborn:     ", sns.__version__)
print("nltk:        ", nltk.__version__)
print("umap:        ", umap.__version__)
print("pymupdf:     ", pymupdf.__version__)
# Out:
# c:\桌面\COADING\Python\data_mining\DM2025Labs\DM2025-Lab2-Exercise\.venv\Lib\site-packages\tensorflow_hub\__init__.py:61: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version
# WARNING:tensorflow:From c:\桌面\COADING\Python\data_mining\DM2025Labs\DM2025-Lab2-Exercise\.venv\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# ✅ Installed package versions:
# ----------------------------------
# gensim:       4.3.3
# tensorflow:   2.20.0
# keras:        3.11.3
# pandas:       2.3.2
# numpy:        1.26.4
# matplotlib:   3.10.6
# plotly:       6.3.0
# seaborn:      0.13.2
# nltk:         3.9.1
# umap:         0.5.9.post2
# pymupdf:      1.26.4
